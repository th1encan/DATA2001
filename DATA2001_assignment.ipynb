# %% [markdown]
# # DATA2001 Group Assingment

# %%
from IPython.display import HTML
HTML('''
    <style> body {font-family: "Roboto Condensed Light", "Roboto Condensed";} h2 {padding: 10px 12px; background-color: #E64626; position: static; color: #ffffff; font-size: 40px;} .text_cell_render p { font-size: 15px; } .text_cell_render h1 { font-size: 30px; } h1 {padding: 10px 12px; background-color: #E64626; color: #ffffff; font-size: 40px;} .text_cell_render h3 { padding: 10px 12px; background-color: #0148A4; position: static; color: #ffffff; font-size: 20px;} h4:before{ 
    content: "@"; font-family:"Wingdings"; font-style:regular; margin-right: 4px;} .text_cell_render h4 {padding: 8px; font-family: "Roboto Condensed Light"; position: static; font-style: italic; background-color: #FFB800; color: #ffffff; font-size: 18px; text-align: center; border-radius: 5px;}input[type=submit] {background-color: #E64626; border: solid; border-color: #734036; color: white; padding: 8px 16px; text-decoration: none; margin: 4px 2px; cursor: pointer; border-radius: 20px;}</style>
''')
# Out:
#     <style> body {font-family: "Roboto Condensed Light", "Roboto Condensed";} h2 {padding: 10px 12px; background-color: #E64626; position: static; color: #ffffff; font-size: 40px;} .text_cell_render p { font-size: 15px; } .text_cell_render h1 { font-size: 30px; } h1 {padding: 10px 12px; background-color: #E64626; color: #ffffff; font-size: 40px;} .text_cell_render h3 { padding: 10px 12px; background-color: #0148A4; position: static; color: #ffffff; font-size: 20px;} h4:before{
#     content: "@"; font-family:"Wingdings"; font-style:regular; margin-right: 4px;} .text_cell_render h4 {padding: 8px; font-family: "Roboto Condensed Light"; position: static; font-style: italic; background-color: #FFB800; color: #ffffff; font-size: 18px; text-align: center; border-radius: 5px;}input[type=submit] {background-color: #E64626; border: solid; border-color: #734036; color: white; padding: 8px 16px; text-decoration: none; margin: 4px 2px; cursor: pointer; border-radius: 20px;}</style>

# %% [markdown]
# ## Task 1

# %% [markdown]
# Load all the libraries needed.

# %%
import pandas as pd 
import numpy as np
import plotly.express as px 
import requests 
import geopandas as gpd
from shapely.geometry import Point, Polygon, MultiPolygon
from geoalchemy2 import Geometry, WKTElement
import matplotlib.pyplot as plt

from sqlalchemy import create_engine
from sqlalchemy import text
import psycopg2
import psycopg2.extras
import json
import os
import plotly.io as pio
pio.renderers.default = 'iframe'

credentials = "Credentials.json"

def pgconnect(credential_filepath, db_schema="public"):
    with open(credential_filepath) as f:
        db_conn_dict = json.load(f)
        host       = db_conn_dict['host']
        db_user    = db_conn_dict['user']
        db_pw      = db_conn_dict['password']
        default_db = db_conn_dict['user']
        port       = db_conn_dict['port']
        try:
            db = create_engine(f'postgresql+psycopg2://{db_user}:{db_pw}@{host}:{port}/{default_db}', echo=False)
            conn = db.connect()
            print('Connected successfully.')
        except Exception as e:
            print("Unable to connect to the database.")
            print(e)
            db, conn = None, None
        return db,conn

# %% [markdown]
# Check that connection to PGAdmin server is successful.

# %%
db, conn = pgconnect(credentials)
# Out:
# Connected successfully.

# %% [markdown]
# Use the following helper function which produces all output as a Pandas dataframe by default (and handles other small things like incorporating the `.text()` function):

# %%
def query(conn, sqlcmd, args=None, df=True):
    result = pd.DataFrame() if df else None
    try:
        if df:
            result = pd.read_sql_query(sqlcmd, conn, params=args)
        else:
            result = conn.execute(text(sqlcmd), args).fetchall()
            result = result[0] if len(result) == 1 else result
    except Exception as e:
        print("Error encountered: ", e, sep='\n')
    return result

# %% [markdown]
# Next, we define the schema and populate the table for each of the datasets needed. In the process some data cleaning has to be done to deal with NULL placeholders in certain datasets. We have a combination of spatial data and usual normalised data to load into PostgreSQL server. Also take care of indexing for each dataset.

# %% [markdown]
# First, we do this for income data. Data cleaning needs to done for this dataset so 'np' place holder for NULL needs to be converted to 0 for numerical columns

# %%
incomedata = pd.read_csv('Income.csv')
incomedata.columns = map(str.lower, incomedata.columns)

incomedata = incomedata.replace('np', pd.NA)


numeric_cols = ['earners', 'median_income', 'mean_income']
for col in numeric_cols:
    incomedata[col] = pd.to_numeric(incomedata[col], errors='coerce')

incomedata[numeric_cols] = incomedata[numeric_cols].fillna(0)

incomedata.head()
# Out:
#    sa2_code21                         sa2_name  earners median_age  \
# 0   101021007                        Braidwood   2467.0         51
# 1   101021008                          Karabar   5103.0         42
# 2   101021009                       Queanbeyan   7028.0         39
# 3   101021010                Queanbeyan - East   3398.0         39
# 4   101021012  Queanbeyan West - Jerrabomberra   8422.0         44
#
#    median_income  mean_income
# 0        46640.0      68904.0
# 1        65564.0      69672.0
# 2        63528.0      69174.0
# 3        66148.0      74162.0
# 4        78630.0      91981.0

# %%
conn.execute(text("""
DROP TABLE IF EXISTS income;
CREATE TABLE income(
    sa2_code21 INT PRIMARY KEY,
    sa2_name VARCHAR(100),
    earners INT,
    median_income NUMERIC,
    mean_income NUMERIC
);
    CREATE INDEX income_median_income_ind ON income(median_income)
"""))


incomedata = incomedata[['sa2_code21', 'sa2_name', 'earners', 'median_income', 'mean_income']]
incomedata.to_sql("income", con=conn, if_exists='append', index=False)
query(conn, "select * from income")
# Out:
#      sa2_code21                         sa2_name  earners  median_income  \
# 0     101021007                        Braidwood     2467        46640.0
# 1     101021008                          Karabar     5103        65564.0
# 2     101021009                       Queanbeyan     7028        63528.0
# 3     101021010                Queanbeyan - East     3398        66148.0
# 4     101021012  Queanbeyan West - Jerrabomberra     8422        78630.0
# ..          ...                              ...      ...            ...
# 637   128021537              Royal National Park       14        36980.0
# 638   128021538            Sutherland - Kirrawee    13895        64940.0
# 639   128021607                         Engadine    10239        63695.0
# 640   128021608             Loftus - Yarrawarrah     4424        63087.0
# 641   128021609                 Woronora Heights     2491        65460.0
#
#      mean_income
# 0        68904.0
# 1        69672.0
# 2        69174.0
# 3        74162.0
# 4        91981.0
# ..           ...
# 637      47584.0
# 638      74867.0
# 639      72995.0
# 640      76440.0
# 641      82717.0
#
# [642 rows x 5 columns]

# %% [markdown]
# Next, for businesses data. In this case we need to make a composite primary key since there are several industries in the same SA2 area so SA2 code cannot be unique in each row.

# %%
businessdata = pd.read_csv('Businesses.csv')
businessdata.columns = map(str.lower, businessdata.columns)

businessdata.columns
# Out:
# Index(['industry_code', 'industry_name', 'sa2_code', 'sa2_name',
#        '0_to_50k_businesses', '50k_to_200k_businesses',
#        '200k_to_2m_businesses', '2m_to_5m_businesses', '5m_to_10m_businesses',
#        '10m_or_more_businesses', 'total_businesses'],
#       dtype='object')

# %%
conn.execute(text("""
DROP TABLE IF EXISTS businesses;
CREATE TABLE businesses(
    sa2_code INT,
    sa2_name VARCHAR(100),
    industry_code CHAR(1),
    industry_name VARCHAR(100),
    total_businesses INT,
    PRIMARY KEY (sa2_code, industry_code)
);
    CREATE INDEX businesses_sa2_code_ind ON businesses(sa2_code)         
"""))

businessdata = businessdata[['sa2_code', 'sa2_name', 'industry_code', 'industry_name', 'total_businesses']]
businessdata.to_sql("businesses", con=conn, if_exists= 'append', index = False)
query(conn, "select * from businesses")
# Out:
#         sa2_code                         sa2_name industry_code  \
# 0      101021007                        Braidwood             A
# 1      101021008                          Karabar             A
# 2      101021009                       Queanbeyan             A
# 3      101021010                Queanbeyan - East             A
# 4      101021012  Queanbeyan West - Jerrabomberra             A
# ...          ...                              ...           ...
# 12212  128021538            Sutherland - Kirrawee             S
# 12213  128021607                         Engadine             S
# 12214  128021608             Loftus - Yarrawarrah             S
# 12215  128021609                 Woronora Heights             S
# 12216  199999499                Currently Unknown             S
#
#                            industry_name  total_businesses
# 0      Agriculture, Forestry and Fishing               296
# 1      Agriculture, Forestry and Fishing                 9
# 2      Agriculture, Forestry and Fishing                15
# 3      Agriculture, Forestry and Fishing                 3
# 4      Agriculture, Forestry and Fishing                16
# ...                                  ...               ...
# 12212                     Other Services               152
# 12213                     Other Services                87
# 12214                     Other Services                22
# 12215                     Other Services                 9
# 12216                     Other Services               190
#
# [12217 rows x 5 columns]

# %% [markdown]
# Next, for population data. In task 3 the schools metric accounts for demographic at the age range of 0-19 so we will create such a column for convenience.

# %%
popdata = pd.read_csv('Population.csv')
popdata.columns = map(str.lower, popdata.columns)

popdata['young_people'] = (
    popdata['0-4_people'] +
    popdata['5-9_people'] +
    popdata['10-14_people'] +
    popdata['15-19_people']
)

popdata.head()
# Out:
#     sa2_code                     sa2_name  0-4_people  5-9_people  \
# 0  102011028     Avoca Beach - Copacabana         424         522
# 1  102011029  Box Head - MacMasters Beach         511         666
# 2  102011030              Calga - Kulnura         200         225
# 3  102011031          Erina - Green Point         683         804
# 4  102011032        Gosford - Springfield        1164        1044
#
#    10-14_people  15-19_people  20-24_people  25-29_people  30-34_people  \
# 0           623           552           386           222           306
# 1           702           592           461           347           420
# 2           258           278           274           227           214
# 3           880           838           661           502           587
# 4          1084          1072          1499          1864          1750
#
#    35-39_people  ...  50-54_people  55-59_people  60-64_people  65-69_people  \
# 0           416  ...           602           570           520           464
# 1           535  ...           749           794           895           863
# 2           286  ...           436           422           397           327
# 3           757  ...           882           901           930           917
# 4          1520  ...          1241          1377          1285          1166
#
#    70-74_people  75-79_people  80-84_people  85-and-over_people  total_people  \
# 0           369           226           142                  70          7530
# 1           925           603           331                 264         11052
# 2           264           190           100                  75          4748
# 3          1065           976           773                1028         14803
# 4           949           664           476                 537         21346
#
#    young_people
# 0          2121
# 1          2471
# 2           961
# 3          3205
# 4          4364
#
# [5 rows x 22 columns]

# %%
conn.execute(text("""
DROP TABLE IF EXISTS population;
CREATE TABLE population(
    sa2_code INT PRIMARY KEY,
    sa2_name VARCHAR(100),
    total_people INT, 
    young_people INT
);
"""))


popdata = popdata[['sa2_code', 'sa2_name', 'total_people', 'young_people']]
popdata.to_sql("population", con=conn, if_exists= 'append', index = False)
query(conn, "select * from population")
# Out:
#       sa2_code                     sa2_name  total_people  young_people
# 0    102011028     Avoca Beach - Copacabana          7530          2121
# 1    102011029  Box Head - MacMasters Beach         11052          2471
# 2    102011030              Calga - Kulnura          4748           961
# 3    102011031          Erina - Green Point         14803          3205
# 4    102011032        Gosford - Springfield         21346          4364
# ..         ...                          ...           ...           ...
# 368  128021537          Royal National Park            45            20
# 369  128021538        Sutherland - Kirrawee         23369          5078
# 370  128021607                     Engadine         17379          5118
# 371  128021608         Loftus - Yarrawarrah          7354          2073
# 372  128021609             Woronora Heights          3551           965
#
# [373 rows x 4 columns]

# %% [markdown]
# After done with normal data, we will ingest spatial data which are SA2 Regions, Stops and Schools (In this order).

# %%
sa2_regions = gpd.read_file("SA2_2021_AUST_GDA2020.shp")
sa2_regions = sa2_regions[sa2_regions['GCC_NAME21'] == 'Greater Sydney']
sa2_regions.head()
# Out:
#    SA2_CODE21                   SA2_NAME21 CHG_FLAG21  CHG_LBL21 SA3_CODE21  \
# 28  102011028     Avoca Beach - Copacabana          0  No change      10201
# 29  102011029  Box Head - MacMasters Beach          0  No change      10201
# 30  102011030              Calga - Kulnura          0  No change      10201
# 31  102011031          Erina - Green Point          0  No change      10201
# 32  102011032        Gosford - Springfield          0  No change      10201
#
#    SA3_NAME21 SA4_CODE21     SA4_NAME21 GCC_CODE21      GCC_NAME21 STE_CODE21  \
# 28    Gosford        102  Central Coast      1GSYD  Greater Sydney          1
# 29    Gosford        102  Central Coast      1GSYD  Greater Sydney          1
# 30    Gosford        102  Central Coast      1GSYD  Greater Sydney          1
# 31    Gosford        102  Central Coast      1GSYD  Greater Sydney          1
# 32    Gosford        102  Central Coast      1GSYD  Greater Sydney          1
#
#          STE_NAME21 AUS_CODE21 AUS_NAME21  AREASQKM21  \
# 28  New South Wales        AUS  Australia      6.4376
# 29  New South Wales        AUS  Australia     32.0802
# 30  New South Wales        AUS  Australia    767.9512
# 31  New South Wales        AUS  Australia     33.7934
# 32  New South Wales        AUS  Australia     16.9123
#
#                                            LOCI_URI21  \
# 28  http://linked.data.gov.au/dataset/asgsed3/SA2/...
# 29  http://linked.data.gov.au/dataset/asgsed3/SA2/...
# 30  http://linked.data.gov.au/dataset/asgsed3/SA2/...
# 31  http://linked.data.gov.au/dataset/asgsed3/SA2/...
# 32  http://linked.data.gov.au/dataset/asgsed3/SA2/...
#
#                                              geometry
# 28  POLYGON ((151.41373 -33.46558, 151.41362 -33.4...
# 29  POLYGON ((151.37484 -33.50052, 151.37507 -33.5...
# 30  MULTIPOLYGON (((151.20449 -33.5328, 151.20448 ...
# 31  POLYGON ((151.37194 -33.43698, 151.37288 -33.4...
# 32  POLYGON ((151.32349 -33.42779, 151.32342 -33.4...

# %% [markdown]
# The functions we'll be leveraging for geographical operations rely on PostGIS (the spatial extension to PostgreSQL) being installed on the database - the below query confirms it is correctly configured.

# %%
query(conn, "select PostGIS_Version()")
# Out:
#                          postgis_version
# 0  3.4 USE_GEOS=1 USE_PROJ=1 USE_STATS=1

# %% [markdown]
# Next we will transform the polygons whilst conducting the WKT conversion. In this case we use GDA2020 so srid is 7844 (seen from the prj file of the dataset)

# %%
srid = 7844
def create_wkt_element(geom, srid):
    if geom.geom_type == 'Polygon':
        geom = MultiPolygon([geom])
    return WKTElement(geom.wkt, srid)

sa2_regions_og = sa2_regions.copy()  # creating a copy of the original for later
sa2_regions['geom'] = sa2_regions['geometry'].apply(lambda x: create_wkt_element(geom=x,srid=srid))  # applying the function
sa2_regions = sa2_regions.drop(columns="geometry")  # deleting the old copy

# %%
sa2_regions.columns = map(str.lower, sa2_regions.columns)
sa2_regions.head()
# Out:
#    sa2_code21                   sa2_name21 chg_flag21  chg_lbl21 sa3_code21  \
# 28  102011028     Avoca Beach - Copacabana          0  No change      10201
# 29  102011029  Box Head - MacMasters Beach          0  No change      10201
# 30  102011030              Calga - Kulnura          0  No change      10201
# 31  102011031          Erina - Green Point          0  No change      10201
# 32  102011032        Gosford - Springfield          0  No change      10201
#
#    sa3_name21 sa4_code21     sa4_name21 gcc_code21      gcc_name21 ste_code21  \
# 28    Gosford        102  Central Coast      1GSYD  Greater Sydney          1
# 29    Gosford        102  Central Coast      1GSYD  Greater Sydney          1
# 30    Gosford        102  Central Coast      1GSYD  Greater Sydney          1
# 31    Gosford        102  Central Coast      1GSYD  Greater Sydney          1
# 32    Gosford        102  Central Coast      1GSYD  Greater Sydney          1
#
#          ste_name21 aus_code21 aus_name21  areasqkm21  \
# 28  New South Wales        AUS  Australia      6.4376
# 29  New South Wales        AUS  Australia     32.0802
# 30  New South Wales        AUS  Australia    767.9512
# 31  New South Wales        AUS  Australia     33.7934
# 32  New South Wales        AUS  Australia     16.9123
#
#                                            loci_uri21  \
# 28  http://linked.data.gov.au/dataset/asgsed3/SA2/...
# 29  http://linked.data.gov.au/dataset/asgsed3/SA2/...
# 30  http://linked.data.gov.au/dataset/asgsed3/SA2/...
# 31  http://linked.data.gov.au/dataset/asgsed3/SA2/...
# 32  http://linked.data.gov.au/dataset/asgsed3/SA2/...
#
#                                                  geom
# 28  MULTIPOLYGON (((151.413733024921 -33.465580583...
# 29  MULTIPOLYGON (((151.37484081570685 -33.5005199...
# 30  MULTIPOLYGON (((151.20449037540152 -33.5328022...
# 31  MULTIPOLYGON (((151.37193611462118 -33.4369790...
# 32  MULTIPOLYGON (((151.32348639265098 -33.4277852...

# %% [markdown]
# Now we can ingest the sa2 region dataset into PostgreSQL server. Take care of spatial index.

# %%
conn.execute(text("""DROP TABLE IF EXISTS sa2_regions;
CREATE TABLE sa2_regions (
    sa2_code21 INT PRIMARY KEY,
    sa2_name21 VARCHAR(100),
    sa4_code21 INT,
    sa4_name21 VARCHAR(100),
    areasqkm21 NUMERIC,
    geom GEOMETRY(MULTIPOLYGON,7844)
);   
    CREATE INDEX sa2_regions_geom_ind ON sa2_regions USING GIST (geom)"""
))

sa2_regions = sa2_regions[['sa2_code21', 'sa2_name21', 'sa4_code21', 'sa4_name21', 'areasqkm21', 'geom']]
sa2_regions.to_sql("sa2_regions", conn, if_exists='append', index=False, dtype={'geom': Geometry('MULTIPOLYGON', srid)})
query(conn, "select * from sa2_regions limit 10")
# Out:
#    sa2_code21                   sa2_name21  sa4_code21  \
# 0   102011028     Avoca Beach - Copacabana         102
# 1   102011029  Box Head - MacMasters Beach         102
# 2   102011030              Calga - Kulnura         102
# 3   102011031          Erina - Green Point         102
# 4   102011032        Gosford - Springfield         102
# 5   102011033                      Kariong         102
# 6   102011034  Kincumber - Picketts Valley         102
# 7   102011035                       Narara         102
# 8   115011555          Castle Hill - North         115
# 9   119031667                    Penshurst         119
#
#                                sa4_name21  areasqkm21  \
# 0                           Central Coast      6.4376
# 1                           Central Coast     32.0802
# 2                           Central Coast    767.9512
# 3                           Central Coast     33.7934
# 4                           Central Coast     16.9123
# 5                           Central Coast      8.3063
# 6                           Central Coast     11.7169
# 7                           Central Coast      7.7021
# 8  Sydney - Baulkham Hills and Hawkesbury      6.8149
# 9               Sydney - Inner South West      1.6722
#
#                                                 geom
# 0  0106000020A41E0000010000000103000000010000005E...
# 1  0106000020A41E00000100000001030000000100000010...
# 2  0106000020A41E00000200000001030000000100000085...
# 3  0106000020A41E00000100000001030000000100000041...
# 4  0106000020A41E0000010000000103000000010000007E...
# 5  0106000020A41E0000010000000103000000010000000F...
# 6  0106000020A41E00000100000001030000000100000029...
# 7  0106000020A41E00000100000001030000000100000009...
# 8  0106000020A41E000001000000010300000001000000FA...
# 9  0106000020A41E000001000000010300000001000000A7...

# %% [markdown]
# Next is the public transport stops data.

# %%
stops = pd.read_csv('Stops.txt')
stops.head()
# Out:
#   stop_id  stop_code                             stop_name   stop_lat  \
# 0  200039   200039.0     Central Station, Eddy Av, Stand A -33.882206
# 1  200054   200054.0     Central Station, Eddy Av, Stand D -33.882042
# 2  200060        NaN                       Central Station -33.884084
# 3  201510        NaN                       Redfern Station -33.891690
# 4  201646   201646.0  Redfern Station, Gibbons St, Stand B -33.893329
#
#      stop_lon  location_type parent_station  wheelchair_boarding platform_code
# 0  151.206665            NaN         200060                    0           NaN
# 1  151.206991            NaN         200060                    0           NaN
# 2  151.206292            1.0            NaN                    0           NaN
# 3  151.198866            1.0            NaN                    0           NaN
# 4  151.198882            NaN         201510                    0           NaN

# %%
stops['geom'] = gpd.points_from_xy(stops.stop_lat, stops.stop_lon)  # creating the geometry column
stops = stops.drop(columns=['stop_lat', 'stop_lon'])  # removing the old latitude/longitude fields
stops.head()
# Out:
#   stop_id  stop_code                             stop_name  location_type  \
# 0  200039   200039.0     Central Station, Eddy Av, Stand A            NaN
# 1  200054   200054.0     Central Station, Eddy Av, Stand D            NaN
# 2  200060        NaN                       Central Station            1.0
# 3  201510        NaN                       Redfern Station            1.0
# 4  201646   201646.0  Redfern Station, Gibbons St, Stand B            NaN
#
#   parent_station  wheelchair_boarding platform_code                     geom
# 0         200060                    0           NaN  POINT (-33.882 151.207)
# 1         200060                    0           NaN  POINT (-33.882 151.207)
# 2            NaN                    0           NaN  POINT (-33.884 151.206)
# 3            NaN                    0           NaN  POINT (-33.892 151.199)
# 4         201510                    0           NaN  POINT (-33.893 151.199)

# %%
srid = 4326
stops['geom'] = stops['geom'].apply(lambda x: WKTElement(x.wkt, srid=srid))
stops
# Out:
#         stop_id  stop_code                             stop_name  \
# 0        200039   200039.0     Central Station, Eddy Av, Stand A
# 1        200054   200054.0     Central Station, Eddy Av, Stand D
# 2        200060        NaN                       Central Station
# 3        201510        NaN                       Redfern Station
# 4        201646   201646.0  Redfern Station, Gibbons St, Stand B
# ...         ...        ...                                   ...
# 114713   212753   212753.0     Sydney Olympic Park Wharf, Side B
# 114714  2137185  2137185.0                Cabarita Wharf, Side A
# 114715  2137186  2137186.0                Cabarita Wharf, Side B
# 114716    21501    21501.0                      Parramatta Wharf
# 114717  2150112        NaN                      Parramatta Wharf
#
#         location_type parent_station  wheelchair_boarding platform_code  \
# 0                 NaN         200060                    0           NaN
# 1                 NaN         200060                    0           NaN
# 2                 1.0            NaN                    0           NaN
# 3                 1.0            NaN                    0           NaN
# 4                 NaN         201510                    0           NaN
# ...               ...            ...                  ...           ...
# 114713            NaN          21271                    1             B
# 114714            NaN          21371                    1            1A
# 114715            NaN          21371                    1            1B
# 114716            NaN        2150112                    1           NaN
# 114717            1.0            NaN                    1           NaN
#
#                                               geom
# 0        POINT (-33.8822064874687 151.20666465471)
# 1        POINT (-33.8820421431408 151.20699145565)
# 2       POINT (-33.8840842535493 151.206292455081)
# 3       POINT (-33.8916900512711 151.198866071817)
# 4       POINT (-33.8933293130144 151.198881722942)
# ...                                            ...
# 114713   POINT (-33.8220164586429 151.07879697831)
# 114714  POINT (-33.8406690716775 151.116926480557)
# 114715  POINT (-33.8407691073139 151.116898892402)
# 114716  POINT (-33.8139042429414 151.010576673346)
# 114717  POINT (-33.8139523874985 151.010481768913)
#
# [114718 rows x 8 columns]

# %%
conn.execute(text("""DROP TABLE IF EXISTS stops;
CREATE TABLE stops (
    stop_id VARCHAR(20) PRIMARY KEY,
    stop_name VARCHAR(100),
    wheelchair_boarding INT,
    geom GEOMETRY(POINT,4326)
);
    CREATE INDEX stops_geom_ind ON stops USING GIST (geom)"""
))

stops = stops[['stop_id', 'stop_name', 'wheelchair_boarding', 'geom']]
stops.to_sql('stops', conn, if_exists='append', index=False, dtype={'geom': Geometry('POINT', srid)})
query(conn, "select * from stops limit 10")
# Out:
#   stop_id                             stop_name  wheelchair_boarding  \
# 0  200039     Central Station, Eddy Av, Stand A                    0
# 1  200054     Central Station, Eddy Av, Stand D                    0
# 2  200060                       Central Station                    0
# 3  201510                       Redfern Station                    0
# 4  201646  Redfern Station, Gibbons St, Stand B                    0
# 5  204230            St Peters Station, King St                    0
# 6  204311         King St Opp St Peters Station                    0
# 7  204313         Erskineville Rd At Charles St                    0
# 8  204320        Erskineville Rd At Prospect St                    0
# 9  204410                     St Peters Station                    0
#
#                                                 geom
# 0  0101000020E6100000A1FF6524ECF040C0FFA631FF9CE6...
# 1  0101000020E6100000E33DC7C1E6F040C02F928BAC9FE6...
# 2  0101000020E61000008FF33DAC29F140C0817FA2F299E6...
# 3  0101000020E610000060304CE622F240C09E57611C5DE6...
# 4  0101000020E61000003DFA6B9D58F240C0DBF9333D5DE6...
# 5  0101000020E610000076DF921A02F440C0B31F3BB6CBE5...
# 6  0101000020E6100000627AB7A805F440C0AFE292CACDE5...
# 7  0101000020E61000004F71D1CD29F340C04D466749E9E5...
# 8  0101000020E61000007FD9B1E328F340C0AC12B4FDE2E5...
# 9  0101000020E6100000FECD638521F440C06EC9C4A4C8E5...

# %% [markdown]
# Next is the schools datasets. Since datasets are divided into 3 types of school, we will generate 3 tables.

# %%
primary_sch = gpd.read_file("catchments_primary.shp")

primary_sch.columns = map(str.lower, primary_sch.columns)
primary_sch.head()
# Out:
#   use_id catch_type         use_desc  add_date kindergart year1 year2 year3  \
# 0   2838    PRIMARY       Parklea PS  20181210          Y     Y     Y     Y
# 1   2404    PRIMARY    Lindfield EPS  20211219          Y     Y     Y     Y
# 2   4393    PRIMARY  Carlingford WPS  20220223          Y     Y     Y     Y
# 3   4615    PRIMARY   Caddies Ck  PS  20181210          Y     Y     Y     Y
# 4   3918    PRIMARY       Killara PS  20211219          Y     Y     Y     Y
#
#   year4 year5 year6 year7 year8 year9 year10 year11 year12 priority  \
# 0     Y     Y     Y     N     N     N      N      N      N     None
# 1     Y     Y     Y     N     N     N      N      N      N     None
# 2     Y     Y     Y     N     N     N      N      N      N     None
# 3     Y     Y     Y     N     N     N      N      N      N     None
# 4     Y     Y     Y     N     N     N      N      N      N     None
#
#                                             geometry
# 0  POLYGON ((150.93564 -33.71612, 150.93715 -33.7...
# 1  POLYGON ((151.18336 -33.74748, 151.18443 -33.7...
# 2  POLYGON ((151.04518 -33.77303, 151.04526 -33.7...
# 3  POLYGON ((150.92567 -33.7296, 150.92602 -33.72...
# 4  POLYGON ((151.15379 -33.75586, 151.15404 -33.7...

# %%
srid = 4283 #same for all school types

primary_sch_og = primary_sch.copy()  # creating a copy of the original for later
primary_sch['geom'] = primary_sch['geometry'].apply(lambda x: create_wkt_element(geom=x,srid=srid))  # applying the function
primary_sch = primary_sch.drop(columns="geometry")  # deleting the old copy
primary_sch.head()
# Out:
#   use_id catch_type         use_desc  add_date kindergart year1 year2 year3  \
# 0   2838    PRIMARY       Parklea PS  20181210          Y     Y     Y     Y
# 1   2404    PRIMARY    Lindfield EPS  20211219          Y     Y     Y     Y
# 2   4393    PRIMARY  Carlingford WPS  20220223          Y     Y     Y     Y
# 3   4615    PRIMARY   Caddies Ck  PS  20181210          Y     Y     Y     Y
# 4   3918    PRIMARY       Killara PS  20211219          Y     Y     Y     Y
#
#   year4 year5 year6 year7 year8 year9 year10 year11 year12 priority  \
# 0     Y     Y     Y     N     N     N      N      N      N     None
# 1     Y     Y     Y     N     N     N      N      N      N     None
# 2     Y     Y     Y     N     N     N      N      N      N     None
# 3     Y     Y     Y     N     N     N      N      N      N     None
# 4     Y     Y     Y     N     N     N      N      N      N     None
#
#                                                 geom
# 0  MULTIPOLYGON (((150.93563850416004 -33.7161211...
# 1  MULTIPOLYGON (((151.1833640465581 -33.74748398...
# 2  MULTIPOLYGON (((151.0451821055135 -33.77303212...
# 3  MULTIPOLYGON (((150.92567327976582 -33.7296030...
# 4  MULTIPOLYGON (((151.1537883781186 -33.75586174...

# %%
conn.execute(text("""DROP TABLE IF EXISTS primary_sch;
CREATE TABLE primary_sch (
    use_id INT PRIMARY KEY,
    catch_type VARCHAR(50),
    geom GEOMETRY(MULTIPOLYGON, 4283)
);   
    CREATE INDEX primary_sch_geom_ind ON primary_sch USING GIST (geom)"""
))

primary_sch = primary_sch[['use_id', 'catch_type', 'geom']]
primary_sch.to_sql("primary_sch", conn, if_exists='append', index=False, dtype={'geom': Geometry('MULTIPOLYGON', srid)})
query(conn, "select * from primary_sch limit 10")
# Out:
#    use_id catch_type                                               geom
# 0    2838    PRIMARY  0106000020BB1000000100000001030000000100000078...
# 1    2404    PRIMARY  0106000020BB10000001000000010300000001000000BE...
# 2    4393    PRIMARY  0106000020BB1000000100000001030000000100000065...
# 3    4405    PRIMARY  0106000020BB1000000100000001030000000100000048...
# 4    4615    PRIMARY  0106000020BB1000000100000001030000000100000056...
# 5    3918    PRIMARY  0106000020BB1000000100000001030000000100000042...
# 6    3396    PRIMARY  0106000020BB10000001000000010300000001000000E1...
# 7    2304    PRIMARY  0106000020BB1000000100000001030000000100000001...
# 8    4398    PRIMARY  0106000020BB1000000100000001030000000100000073...
# 9    4286    PRIMARY  0106000020BB10000001000000010300000001000000AE...

# %%
sec_sch = gpd.read_file("catchments_secondary.shp")

sec_sch.columns = map(str.lower, sec_sch.columns)
sec_sch.head()
# Out:
#   use_id catch_type         use_desc  add_date kindergart year1 year2 year3  \
# 0   8503  HIGH_COED     Billabong HS  20200507          N     N     N     N
# 1   8266  HIGH_COED  James Fallon HS  20200507          N     N     N     N
# 2   8505  HIGH_COED        Murray HS  20200507          N     N     N     N
# 3   8458  HIGH_COED     Kingswood HS  20201016          N     N     N     N
# 4   8559  HIGH_COED       Jamison HS  20201016          N     N     N     N
#
#   year4 year5 year6 year7 year8 year9 year10 year11 year12 priority  \
# 0     N     N     N     Y     Y     Y      Y      Y      Y     None
# 1     N     N     N     Y     Y     Y      Y      Y      Y     None
# 2     N     N     N     Y     Y     Y      Y      Y      Y     None
# 3     N     N     N     Y     Y     Y      Y      Y      Y     None
# 4     N     N     N     Y     Y     Y      Y      Y      Y     None
#
#                                             geometry
# 0  POLYGON ((146.67182 -35.31444, 146.6893 -35.31...
# 1  POLYGON ((147.08734 -35.86271, 147.10413 -35.8...
# 2  POLYGON ((146.81448 -35.78341, 146.8125 -35.79...
# 3  MULTIPOLYGON (((150.686 -33.74031, 150.68631 -...
# 4  POLYGON ((150.69513 -33.75627, 150.68936 -33.7...

# %%
sec_sch_og = sec_sch.copy()  # creating a copy of the original for later
sec_sch['geom'] = sec_sch['geometry'].apply(lambda x: create_wkt_element(geom=x,srid=srid))  # applying the function
sec_sch = sec_sch.drop(columns="geometry")  # deleting the old copy
sec_sch.head()
# Out:
#   use_id catch_type         use_desc  add_date kindergart year1 year2 year3  \
# 0   8503  HIGH_COED     Billabong HS  20200507          N     N     N     N
# 1   8266  HIGH_COED  James Fallon HS  20200507          N     N     N     N
# 2   8505  HIGH_COED        Murray HS  20200507          N     N     N     N
# 3   8458  HIGH_COED     Kingswood HS  20201016          N     N     N     N
# 4   8559  HIGH_COED       Jamison HS  20201016          N     N     N     N
#
#   year4 year5 year6 year7 year8 year9 year10 year11 year12 priority  \
# 0     N     N     N     Y     Y     Y      Y      Y      Y     None
# 1     N     N     N     Y     Y     Y      Y      Y      Y     None
# 2     N     N     N     Y     Y     Y      Y      Y      Y     None
# 3     N     N     N     Y     Y     Y      Y      Y      Y     None
# 4     N     N     N     Y     Y     Y      Y      Y      Y     None
#
#                                                 geom
# 0  MULTIPOLYGON (((146.67182402032344 -35.3144375...
# 1  MULTIPOLYGON (((147.08733806259178 -35.8627146...
# 2  MULTIPOLYGON (((146.81447829547324 -35.7834062...
# 3  MULTIPOLYGON (((150.68599834118749 -33.7403060...
# 4  MULTIPOLYGON (((150.69513440644116 -33.7562688...

# %%
conn.execute(text("""DROP TABLE IF EXISTS sec_sch;
CREATE TABLE sec_sch (
    use_id INT PRIMARY KEY,
    catch_type VARCHAR(50),
    geom GEOMETRY(MULTIPOLYGON, 4283)
);   
    CREATE INDEX sec_sch_geom_ind ON sec_sch USING GIST (geom)"""
))

sec_sch = sec_sch[['use_id', 'catch_type', 'geom']]
sec_sch.to_sql("sec_sch", conn, if_exists='append', index=False, dtype={'geom': Geometry('MULTIPOLYGON', srid)})
query(conn, "select * from sec_sch limit 10")
# Out:
#    use_id catch_type                                               geom
# 0    8503  HIGH_COED  0106000020BB100000010000000103000000010000006D...
# 1    8266  HIGH_COED  0106000020BB1000000100000001030000000100000071...
# 2    8559  HIGH_COED  0106000020BB100000010000000103000000020000002F...
# 3    8502  HIGH_COED  0106000020BB100000010000000103000000010000003B...
# 4    8505  HIGH_COED  0106000020BB100000010000000103000000010000003F...
# 5    8458  HIGH_COED  0106000020BB1000000200000001030000000100000096...
# 6    8227  HIGH_COED  0106000020BB100000010000000103000000010000006E...
# 7    8384  HIGH_COED  0106000020BB1000000100000001030000000100000084...
# 8    8404  HIGH_COED  0106000020BB100000010000000103000000010000008F...
# 9    8536  HIGH_COED  0106000020BB1000000100000001030000000100000055...

# %%
f_sch = gpd.read_file("catchments_future.shp")

f_sch.columns = map(str.lower, f_sch.columns)
f_sch_og = f_sch.copy()  # creating a copy of the original for later
f_sch['geom'] = f_sch['geometry'].apply(lambda x: create_wkt_element(geom=x,srid=srid))  # applying the function
f_sch = f_sch.drop(columns="geometry")  # deleting the old copy
f_sch.head()
# Out:
#   use_id catch_type             use_desc  add_date  kindergart  year1  year2  \
# 0   8416  HIGH_COED       Ku-ring-gai HS  20230114           0      0      0
# 1   8161  HIGH_BOYS         Randwick BHS  20200220           0      0      0
# 2   8539  HIGH_COED  SSC Blackwattle Bay  20220609           0      0      0
# 3   8400  HIGH_COED           St Ives HS  20230114           0      0      0
# 4   8555  HIGH_COED          Rose Bay SC  20200220           0      0      0
#
#    year3  year4  year5  year6  year7  year8  year9  year10  year11  year12  \
# 0      0      0      0      0   2024   2024   2024    2024    2024    2024
# 1      0      0      0      0   2024   2024   2024    2024    2024    2024
# 2      0      0      0      0      0      0      0       0    2024    2024
# 3      0      0      0      0   2024   2024   2024    2024    2024    2024
# 4      0      0      0      0   2024   2024   2024    2024    2024    2024
#
#                                                 geom
# 0  MULTIPOLYGON (((151.19848917708944 -33.5398987...
# 1  MULTIPOLYGON (((151.27151530428182 -33.9140183...
# 2  MULTIPOLYGON (((151.15292370935092 -33.8393921...
# 3  MULTIPOLYGON (((151.17793729938725 -33.6982001...
# 4  MULTIPOLYGON (((151.28072275958445 -33.8328728...

# %%
conn.execute(text("""DROP TABLE IF EXISTS f_sch;
CREATE TABLE f_sch (
    use_id INT PRIMARY KEY,
    catch_type VARCHAR(50),
    geom GEOMETRY(MULTIPOLYGON, 4283)
);   
    CREATE INDEX f_sch_geom_ind ON f_sch USING GIST (geom)"""
))

f_sch = f_sch[['use_id', 'catch_type', 'geom']]
f_sch.to_sql("f_sch", conn, if_exists='append', index=False, dtype={'geom': Geometry('MULTIPOLYGON', srid)})
query(conn, "select * from f_sch limit 10")
# Out:
#    use_id    catch_type                                               geom
# 0    8416     HIGH_COED  0106000020BB1000000100000001030000000100000090...
# 1    8161     HIGH_BOYS  0106000020BB100000010000000103000000010000006F...
# 2    8539     HIGH_COED  0106000020BB10000001000000010300000001000000E3...
# 3    8286     HIGH_COED  0106000020BB1000000100000001030000000100000099...
# 4    4524       PRIMARY  0106000020BB1000000100000001030000000100000060...
# 5    8554     HIGH_COED  0106000020BB10000001000000010300000001000000FE...
# 6    8400     HIGH_COED  0106000020BB1000000100000001030000000100000060...
# 7    8555     HIGH_COED  0106000020BB100000010000000103000000010000000C...
# 8    8135     HIGH_COED  0106000020BB100000010000000103000000010000001F...
# 9    8556  CENTRAL_HIGH  0106000020BB1000000100000001030000000100000028...

# %% [markdown]
# # Task 2

# %% [markdown]
# We will query the NSW POI API.

# %%
params = {
    'where': "poiname='FISHER LIBRARY SYDNEY UNIVERSITY'",
    'outFields': '*',
    'returnGeometry': 'true',
    'f': 'json'
}

response = requests.get("https://maps.six.nsw.gov.au/arcgis/rest/services/public/NSW_POI/MapServer", params=params)
response
# Out:
# <Response [200]>

# %%
def nearbyPOI(coordinates, boxsize=5, filters={}):
    baseURL = 'https://maps.six.nsw.gov.au/arcgis/rest/services/public/NSW_POI/MapServer'
    lat, lon = round(coordinates[0], 5), round(coordinates[1], 5)
    delta = boxsize/(100*2)  # Australia's DCCEEW defines 1 of a degree of latitude as roughly 1/100th of a km, hence division by 100. The extra division by 2 is to ensure the full width is divided in each direction (e.g. 2.5km left and right)
    params = {
        'geometry': f'"xmin":{lon-delta},"ymin":{lat-delta},"xmax":{lon+delta},"ymax:{lat+delta}"',
        'outFields': '*',
        'returnGeometry': 'true',
        'f': 'json'
    }
    response = requests.get(baseURL, params)
    return json.loads(response.text)['features']

# %%
#ChatGPT Solution
def nearbyPOI(coordinates, boxsize=1, filters=None):
    baseURL = "https://maps.six.nsw.gov.au/arcgis/rest/services/public/NSW_POI/MapServer/0/query"
    lat, lon = coordinates
    delta = boxsize / (100 * 2)

    params = {
        'geometry': json.dumps({
            "xmin": lon - delta,
            "ymin": lat - delta,
            "xmax": lon + delta,
            "ymax": lat + delta,
            "spatialReference": {"wkid": 4326}
        }),
        'geometryType': 'esriGeometryEnvelope',
        'spatialRel': 'esriSpatialRelIntersects',
        'outFields': '*',
        'returnGeometry': 'true',
        'f': 'json'
    }

    response = requests.get(baseURL, params=params)
    
    # Debug the response
    try:
        data = response.json()
    except json.JSONDecodeError:
        print("Failed to decode JSON:")
        print(response.text)
        return []

    if 'features' not in data:
        print("No features found. Full response:")
        print(data)
        return []

    return data['features']

# %%
coordinates = (-33.885841083791824, 151.18879524522902) 
results = nearbyPOI(coordinates, boxsize=1)
results
# Out:
# [{'attributes': {'objectid': 2631,
#    'topoid': 500301659,
#    'poigroup': 3,
#    'poitype': 'Park',
#    'poiname': 'RESIDENTS PARK',
#    'poilabel': 'RESIDENTS PARK',
#    'poilabeltype': 'NAMED',
#    'poialtlabel': None,
#    'poisourcefeatureoid': 61,
#    'accesscontrol': 1,
#    'startdate': 1285588392000,
#    'enddate': 32503680000000,
#    'lastupdate': 1285588392535,
#    'msoid': 90267,
#    'centroidid': None,
#    'shapeuuid': '5cb05e3e-2a29-3861-9afa-bb18de788110',
#    'changetype': 'I',
#    'processstate': None,
#    'urbanity': 'U'},
#   'geometry': {'x': 151.1881886978318, 'y': -33.88365602309533}},
#  {'attributes': {'objectid': 3081,
#    'topoid': 500323830,
#    'poigroup': 3,
#    'poitype': 'Sports Field',
#    'poiname': 'ST PAULS OVAL',
#    'poilabel': 'ST PAULS OVAL',
#    'poilabeltype': 'NAMED',
#    'poialtlabel': None,
#    'poisourcefeatureoid': 67,
#    'accesscontrol': 1,
#    'startdate': 1285588392000,
#    'enddate': 32503680000000,
#    'lastupdate': 1285588392535,
#    'msoid': 99056,
#    'centroidid': None,
#    'shapeuuid': '0b1c85ee-56fc-362b-b1e5-4d1c0075dc26',
#    'changetype': 'I',
#    'processstate': None,
#    'urbanity': 'U'},
#   'geometry': {'x': 151.18853069185042, 'y': -33.88979530015789}},
#  {'attributes': {'objectid': 3082,
#    'topoid': 500323874,
#    'poigroup': 2,
#    'poitype': 'University',
#    'poiname': 'THE UNIVERSITY OF SYDNEY CAMPERDOWN CAMPUS',
#    'poilabel': 'THE UNIVERSITY OF SYDNEY CAMPERDOWN CAMPUS',
#    'poilabeltype': 'NAMED',
#    'poialtlabel': None,
#    'poisourcefeatureoid': 39,
#    'accesscontrol': 1,
#    'startdate': 1295539150000,
#    'enddate': 32503680000000,
#    'lastupdate': 1295539152432,
#    'msoid': 121658,
#    'centroidid': None,
#    'shapeuuid': '8eaa6b25-4fd9-3b35-a021-05cd5a80f8f7',
#    'changetype': 'M',
#    'processstate': None,
#    'urbanity': 'U'},
#   'geometry': {'x': 151.18404387919574, 'y': -33.88809274495354}},
#  {'attributes': {'objectid': 3083,
#    'topoid': 500323885,
#    'poigroup': 1,
#    'poitype': 'Library',
#    'poiname': 'FISHER LIBRARY SYDNEY UNIVERSITY',
#    'poilabel': 'FISHER LIBRARY SYDNEY UNIVERSITY',
#    'poilabeltype': 'NAMED',
#    'poialtlabel': None,
#    'poisourcefeatureoid': 14,
#    'accesscontrol': 1,
#    'startdate': 1344594503000,
#    'enddate': 32503680000000,
#    'lastupdate': 1344594513266,
#    'msoid': 143190,
#    'centroidid': None,
#    'shapeuuid': '71adb868-ad78-3335-adbb-222ed14d68a4',
#    'changetype': 'M',
#    'processstate': None,
#    'urbanity': 'U'},
#   'geometry': {'x': 151.19049355206874, 'y': -33.886316917424516}},
#  {'attributes': {'objectid': 3084,
#    'topoid': 500323930,
#    'poigroup': 1,
#    'poitype': 'Place Of Worship',
#    'poiname': None,
#    'poilabel': 'CHURCH OF SCIENTOLOGY',
#    'poilabeltype': 'DERIVED',
#    'poialtlabel': 'SCIENTOLOGY',
#    'poisourcefeatureoid': 19,
#    'accesscontrol': 1,
#    'startdate': 1285588392000,
#    'enddate': 32503680000000,
#    'lastupdate': 1285588392535,
#    'msoid': 61557,
#    'centroidid': None,
#    'shapeuuid': '8340099d-de71-380a-8ddd-cd6e95949f2b',
#    'changetype': 'I',
#    'processstate': None,
#    'urbanity': 'U'},
#   'geometry': {'x': 151.1936031297135, 'y': -33.882700490025925}},
#  {'attributes': {'objectid': 25908,
#    'topoid': 504377168,
#    'poigroup': 6,
#    'poitype': 'Manmade Waterbody',
#    'poiname': 'LAKE NORTHAM',
#    'poilabel': 'LAKE NORTHAM',
#    'poilabeltype': 'NAMED',
#    'poialtlabel': None,
#    'poisourcefeatureoid': 84,
#    'accesscontrol': 1,
#    'startdate': 1552501037000,
#    'enddate': 32503680000000,
#    'lastupdate': 1552501072915,
#    'msoid': 219575,
#    'centroidid': None,
#    'shapeuuid': '3448f07b-3b2d-3805-a09e-ba30333b09d0',
#    'changetype': 'M',
#    'processstate': None,
#    'urbanity': 'U'},
#   'geometry': {'x': 151.19320416992952, 'y': -33.88518713363017}},
#  {'attributes': {'objectid': 26539,
#    'topoid': 504378644,
#    'poigroup': 1,
#    'poitype': 'Fire Station',
#    'poiname': 'GLEBE FIRE STATION',
#    'poilabel': 'GLEBE FIRE STATION',
#    'poilabeltype': 'NAMED',
#    'poialtlabel': None,
#    'poisourcefeatureoid': 10,
#    'accesscontrol': 1,
#    'startdate': 1285588392000,
#    'enddate': 32503680000000,
#    'lastupdate': 1285588392535,
#    'msoid': 9876,
#    'centroidid': None,
#    'shapeuuid': '64fee7de-43d6-3775-b776-a99c8918ba99',
#    'changetype': 'I',
#    'processstate': None,
#    'urbanity': 'U'},
#   'geometry': {'x': 151.18659576294922, 'y': -33.88122067117969}},
#  {'attributes': {'objectid': 26663,
#    'topoid': 504378896,
#    'poigroup': 3,
#    'poitype': 'Sports Court',
#    'poiname': None,
#    'poilabel': 'TENNIS COURTS',
#    'poilabeltype': 'ALTERNATE',
#    'poialtlabel': 'TENNIS COURTS',
#    'poisourcefeatureoid': 66,
#    'accesscontrol': 1,
#    'startdate': 1285588392000,
#    'enddate': 32503680000000,
#    'lastupdate': 1285588392535,
#    'msoid': 98741,
#    'centroidid': None,
#    'shapeuuid': '5b54e512-d360-3d93-9595-e536aa0a9730',
#    'changetype': 'I',
#    'processstate': None,
#    'urbanity': 'U'},
#   'geometry': {'x': 151.1904434440422, 'y': -33.88526745972515}},
#  {'attributes': {'objectid': 26665,
#    'topoid': 504378906,
#    'poigroup': 3,
#    'poitype': 'Sports Field',
#    'poiname': 'UNIVERSITY OVAL NUMBER TWO',
#    'poilabel': 'UNIVERSITY OVAL NUMBER TWO',
#    'poilabeltype': 'NAMED',
#    'poialtlabel': None,
#    'poisourcefeatureoid': 67,
#    'accesscontrol': 1,
#    'startdate': 1417170896000,
#    'enddate': 32503680000000,
#    'lastupdate': 1417170931768,
#    'msoid': 172352,
#    'centroidid': None,
#    'shapeuuid': '3ddb6c32-4fe2-384c-8144-2c56470f82b5',
#    'changetype': 'M',
#    'processstate': None,
#    'urbanity': 'U'},
#   'geometry': {'x': 151.1848294379454, 'y': -33.88652303536095}},
#  {'attributes': {'objectid': 26666,
#    'topoid': 504378907,
#    'poigroup': 3,
#    'poitype': 'Sports Field',
#    'poiname': 'UNIVERSITY OVAL NUMBER ONE',
#    'poilabel': 'UNIVERSITY OVAL NUMBER ONE',
#    'poilabeltype': 'NAMED',
#    'poialtlabel': None,
#    'poisourcefeatureoid': 67,
#    'accesscontrol': 1,
#    'startdate': 1417170896000,
#    'enddate': 32503680000000,
#    'lastupdate': 1417170931770,
#    'msoid': 172353,
#    'centroidid': None,
#    'shapeuuid': '0f8a79ac-bdf3-3f86-ad0d-183a6555d34b',
#    'changetype': 'M',
#    'processstate': None,
#    'urbanity': 'U'},
#   'geometry': {'x': 151.18501203400166, 'y': -33.88793659245211}},
#  {'attributes': {'objectid': 26667,
#    'topoid': 504378908,
#    'poigroup': 3,
#    'poitype': 'Sports Court',
#    'poiname': None,
#    'poilabel': 'TENNIS COURTS',
#    'poilabeltype': 'ALTERNATE',
#    'poialtlabel': 'TENNIS COURTS',
#    'poisourcefeatureoid': 66,
#    'accesscontrol': 1,
#    'startdate': 1285588392000,
#    'enddate': 32503680000000,
#    'lastupdate': 1285588392535,
#    'msoid': 98364,
#    'centroidid': None,
#    'shapeuuid': 'bc16417d-9b0b-35d4-9ae4-2b26f83df2f9',
#    'changetype': 'I',
#    'processstate': None,
#    'urbanity': 'U'},
#   'geometry': {'x': 151.18796412350235, 'y': -33.8875029509993}},
#  {'attributes': {'objectid': 26668,
#    'topoid': 504378910,
#    'poigroup': 3,
#    'poitype': 'Sports Field',
#    'poiname': 'ST ANDREWS OVAL',
#    'poilabel': 'ST ANDREWS OVAL',
#    'poilabeltype': 'NAMED',
#    'poialtlabel': None,
#    'poisourcefeatureoid': 67,
#    'accesscontrol': 1,
#    'startdate': 1285588392000,
#    'enddate': 32503680000000,
#    'lastupdate': 1285588392535,
#    'msoid': 99790,
#    'centroidid': None,
#    'shapeuuid': '646101b6-be8d-335b-9314-d7c8087e36c3',
#    'changetype': 'I',
#    'processstate': None,
#    'urbanity': 'U'},
#   'geometry': {'x': 151.1847220048273, 'y': -33.8905614070346}},
#  {'attributes': {'objectid': 26674,
#    'topoid': 504378924,
#    'poigroup': 3,
#    'poitype': 'Park',
#    'poiname': 'VICTORIA PARK',
#    'poilabel': 'VICTORIA PARK',
#    'poilabeltype': 'NAMED',
#    'poialtlabel': None,
#    'poisourcefeatureoid': 61,
#    'accesscontrol': 1,
#    'startdate': 1285588392000,
#    'enddate': 32503680000000,
#    'lastupdate': 1285588392535,
#    'msoid': 93840,
#    'centroidid': None,
#    'shapeuuid': '3b66ab08-72fa-33a3-b670-ddb4ffc116f4',
#    'changetype': 'I',
#    'processstate': None,
#    'urbanity': 'U'},
#   'geometry': {'x': 151.1921127069778, 'y': -33.88691676974374}},
#  {'attributes': {'objectid': 26675,
#    'topoid': 504378925,
#    'poigroup': 1,
#    'poitype': 'Post Office',
#    'poiname': 'SYDNEY UNIVERSITY POST OFFICE',
#    'poilabel': 'SYDNEY UNIVERSITY POST OFFICE',
#    'poilabeltype': 'NAMED',
#    'poialtlabel': None,
#    'poisourcefeatureoid': 21,
#    'accesscontrol': 1,
#    'startdate': 1319808298000,
#    'enddate': 32503680000000,
#    'lastupdate': 1319808324826,
#    'msoid': 132681,
#    'centroidid': None,
#    'shapeuuid': 'cd68136a-f083-3f4d-a3d7-e88e48010af4',
#    'changetype': 'M',
#    'processstate': None,
#    'urbanity': 'U'},
#   'geometry': {'x': 151.18757732780568, 'y': -33.88574837738632}},
#  {'attributes': {'objectid': 53911,
#    'topoid': 511797580,
#    'poigroup': 8,
#    'poitype': 'Urban Place',
#    'poiname': 'THE UNIVERSITY OF SYDNEY',
#    'poilabel': 'THE UNIVERSITY OF SYDNEY',
#    'poilabeltype': 'NAMED',
#    'poialtlabel': None,
#    'poisourcefeatureoid': 164,
#    'accesscontrol': 1,
#    'startdate': 1536763238000,
#    'enddate': 32503680000000,
#    'lastupdate': 1536763494189,
#    'msoid': 214323,
#    'centroidid': None,
#    'shapeuuid': '92bf9d88-b272-3552-a6c7-2ea9e9614156',
#    'changetype': 'M',
#    'processstate': None,
#    'urbanity': 'U'},
#   'geometry': {'x': 151.18490442122052, 'y': -33.88671430011861}},
#  {'attributes': {'objectid': 70383,
#    'topoid': 512860061,
#    'poigroup': 1,
#    'poitype': 'Community Facility',
#    'poiname': 'GLEBE TOWN HALL',
#    'poilabel': 'GLEBE TOWN HALL',
#    'poilabeltype': 'NAMED',
#    'poialtlabel': None,
#    'poisourcefeatureoid': 162,
#    'accesscontrol': 1,
#    'startdate': 1443790574000,
#    'enddate': 32503680000000,
#    'lastupdate': 1443790872000,
#    'msoid': 196413,
#    'centroidid': None,
#    'shapeuuid': '1b1e2a35-8946-308c-83ee-e57ea890ba03',
#    'changetype': 'M',
#    'processstate': None,
#    'urbanity': 'U'},
#   'geometry': {'x': 151.18498549147998, 'y': -33.882524105479284}},
#  {'attributes': {'objectid': 70623,
#    'topoid': 512862604,
#    'poigroup': 1,
#    'poitype': 'Community Facility',
#    'poiname': 'ST JOHNS CHURCH HALL',
#    'poilabel': 'ST JOHNS CHURCH HALL',
#    'poilabeltype': 'NAMED',
#    'poialtlabel': None,
#    'poisourcefeatureoid': 162,
#    'accesscontrol': 1,
#    'startdate': 1443790574000,
#    'enddate': 32503680000000,
#    'lastupdate': 1443790872000,
#    'msoid': 196579,
#    'centroidid': None,
#    'shapeuuid': '7c68d33d-689b-337f-966f-7db56c54f8de',
#    'changetype': 'M',
#    'processstate': None,
#    'urbanity': 'U'},
#   'geometry': {'x': 151.18724858303923, 'y': -33.88138157463152}},
#  {'attributes': {'objectid': 107279,
#    'topoid': 515562331,
#    'poigroup': 2,
#    'poitype': 'High School',
#    'poiname': 'AUSTRALIAN PERFORMING ARTS GRAMMAR SCHOOL',
#    'poilabel': 'AUSTRALIAN PERFORMING ARTS GRAMMAR SCHOOL',
#    'poilabeltype': 'NAMED',
#    'poialtlabel': None,
#    'poisourcefeatureoid': 34,
#    'accesscontrol': 1,
#    'startdate': 1374072878000,
#    'enddate': 32503680000000,
#    'lastupdate': 1374073112333,
#    'msoid': 158467,
#    'centroidid': None,
#    'shapeuuid': '435bc87f-3fc7-3afd-a890-d0d755943730',
#    'changetype': 'M',
#    'processstate': None,
#    'urbanity': 'U'},
#   'geometry': {'x': 151.19366048175448, 'y': -33.88430817941234}},
#  {'attributes': {'objectid': 109281,
#    'topoid': 515790676,
#    'poigroup': 1,
#    'poitype': 'Retirement Village',
#    'poiname': "ST JOHN'S VILLAGE",
#    'poilabel': "ST JOHN'S VILLAGE",
#    'poilabeltype': 'NAMED',
#    'poialtlabel': None,
#    'poisourcefeatureoid': 132,
#    'accesscontrol': 1,
#    'startdate': 1384949695000,
#    'enddate': 32503680000000,
#    'lastupdate': 1384949797463,
#    'msoid': 164353,
#    'centroidid': None,
#    'shapeuuid': '355c09e7-040e-33ed-ac01-b65cff286515',
#    'changetype': 'M',
#    'processstate': None,
#    'urbanity': 'U'},
#   'geometry': {'x': 151.18671958223644, 'y': -33.88090060326981}},
#  {'attributes': {'objectid': 115604,
#    'topoid': 517014272,
#    'poigroup': 2,
#    'poitype': 'Primary School',
#    'poiname': 'GLEBE PUBLIC SCHOOL',
#    'poilabel': 'GLEBE PUBLIC SCHOOL',
#    'poilabeltype': 'NAMED',
#    'poialtlabel': None,
#    'poisourcefeatureoid': 36,
#    'accesscontrol': 1,
#    'startdate': 1310035029000,
#    'enddate': 32503680000000,
#    'lastupdate': 1310035091717,
#    'msoid': 127477,
#    'centroidid': None,
#    'shapeuuid': '2f744de9-820d-34b9-b779-04a255038645',
#    'changetype': 'I',
#    'processstate': None,
#    'urbanity': 'U'},
#   'geometry': {'x': 151.19089824040927, 'y': -33.88388095611545}},
#  {'attributes': {'objectid': 130679,
#    'topoid': 517470903,
#    'poigroup': 1,
#    'poitype': 'Community Facility',
#    'poiname': 'PETER FORSYTH AUDITORIUM',
#    'poilabel': 'PETER FORSYTH AUDITORIUM',
#    'poilabeltype': 'NAMED',
#    'poialtlabel': None,
#    'poisourcefeatureoid': 162,
#    'accesscontrol': 1,
#    'startdate': 1443790574000,
#    'enddate': 32503680000000,
#    'lastupdate': 1443790873000,
#    'msoid': 197061,
#    'centroidid': None,
#    'shapeuuid': '4c2d0daf-cd0b-3d64-9891-baad416786f9',
#    'changetype': 'M',
#    'processstate': None,
#    'urbanity': 'U'},
#   'geometry': {'x': 151.19273645668696, 'y': -33.88314048664811}},
#  {'attributes': {'objectid': 130680,
#    'topoid': 517470908,
#    'poigroup': 1,
#    'poitype': 'Community Facility',
#    'poiname': 'GLEBE NEIGHBOURHOOD SERVICE CENTRE',
#    'poilabel': 'GLEBE NEIGHBOURHOOD SERVICE CENTRE',
#    'poilabeltype': 'NAMED',
#    'poialtlabel': None,
#    'poisourcefeatureoid': 162,
#    'accesscontrol': 1,
#    'startdate': 1443790574000,
#    'enddate': 32503680000000,
#    'lastupdate': 1443790873000,
#    'msoid': 197062,
#    'centroidid': None,
#    'shapeuuid': 'aecfa15e-b728-38b6-be46-5dca3a1ad731',
#    'changetype': 'M',
#    'processstate': None,
#    'urbanity': 'U'},
#   'geometry': {'x': 151.1851525889026, 'y': -33.88255207317277}},
#  {'attributes': {'objectid': 138538,
#    'topoid': 518089424,
#    'poigroup': 3,
#    'poitype': 'Park',
#    'poiname': 'ROBYN KEMMIS RESERVE',
#    'poilabel': 'ROBYN KEMMIS RESERVE',
#    'poilabeltype': 'NAMED',
#    'poialtlabel': None,
#    'poisourcefeatureoid': 61,
#    'accesscontrol': 1,
#    'startdate': 1506359251000,
#    'enddate': 32503680000000,
#    'lastupdate': 1506359280000,
#    'msoid': 210100,
#    'centroidid': None,
#    'shapeuuid': 'c736bc3b-5ae1-33d3-a035-a78352b8c77f',
#    'changetype': 'I',
#    'processstate': None,
#    'urbanity': 'U'},
#   'geometry': {'x': 151.1923036043656, 'y': -33.88237733795541}},
#  {'attributes': {'objectid': 163819,
#    'topoid': 504378897,
#    'poigroup': 3,
#    'poitype': 'Swimming Pool Facility',
#    'poiname': 'VICTORIA PARK POOL',
#    'poilabel': 'VICTORIA PARK POOL',
#    'poilabeltype': 'NAMED',
#    'poialtlabel': None,
#    'poisourcefeatureoid': 43,
#    'accesscontrol': 1,
#    'startdate': 1743512465000,
#    'enddate': 32503680000000,
#    'lastupdate': 1743513891586,
#    'msoid': 245423,
#    'centroidid': None,
#    'shapeuuid': '96bb017c-742e-3a92-bf5b-7e3ddba75e56',
#    'changetype': 'M',
#    'processstate': None,
#    'urbanity': 'U'},
#   'geometry': {'x': 151.19231212847933, 'y': -33.88615345049869}}]

# %%
[x['attributes']['poiname'] for x in results if x['attributes']['poiname']]
# Out:
# ['RESIDENTS PARK',
#  'ST PAULS OVAL',
#  'THE UNIVERSITY OF SYDNEY CAMPERDOWN CAMPUS',
#  'FISHER LIBRARY SYDNEY UNIVERSITY',
#  'LAKE NORTHAM',
#  'GLEBE FIRE STATION',
#  'UNIVERSITY OVAL NUMBER TWO',
#  'UNIVERSITY OVAL NUMBER ONE',
#  'ST ANDREWS OVAL',
#  'VICTORIA PARK',
#  'SYDNEY UNIVERSITY POST OFFICE',
#  'THE UNIVERSITY OF SYDNEY',
#  'GLEBE TOWN HALL',
#  'ST JOHNS CHURCH HALL',
#  'AUSTRALIAN PERFORMING ARTS GRAMMAR SCHOOL',
#  "ST JOHN'S VILLAGE",
#  'GLEBE PUBLIC SCHOOL',
#  'PETER FORSYTH AUDITORIUM',
#  'GLEBE NEIGHBOURHOOD SERVICE CENTRE',
#  'ROBYN KEMMIS RESERVE',
#  'VICTORIA PARK POOL']
